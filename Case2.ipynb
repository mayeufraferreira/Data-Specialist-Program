# %%
#Instalação da API do Google que coleta os dados (inclusive avaliações) de aplicativos
pip install google-play-scraper

# %%
#Importação das bibliotecas necessárias
from google_play_scraper import app
from google_play_scraper import Sort, reviews_all
import pandas as pd

#Escolha do app(Zax)
result = app(
    'br.com.zaxapp.app'
)

#Coleta das avaliações
result = reviews_all(
    'br.com.zaxapp.app',
    sleep_milliseconds=0,
    lang='pt-br' #Escolhi todas as avaliações feitas no Brasil, em português
)

#Transformação dos dados em um data frame estruturado
df_data_frame = pd.DataFrame(result)
#Ao rodar esse comando, a coluna com as resposta dos desenvolvedores já normaliza os dados

#Solução para que o pandas exiba todos os dados sem saída truncada
#Nessa solução, retirei a limitação de exibição do data frame ao passar como parâmetro o "None"
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)

#Conferência se a data está no fomarto datetime64[ns] (A coluna já estava no formato)
tipo = df_data_frame['at'].dtype

#Exibição dos dados do data frame
df_data_frame
#Nesse caso a exibição irá mostrar a tabela completa sem restrição dos dados devido a configuração anterior
#Caso seja necessário exibir um número limitado de dados, basta passar o número desejado como parâmetro no lugar do "None"
# Out:
#                                   reviewId              userName  \
# 0     ec77d8f5-01a8-4d27-9315-5e8c81b3de9a   Alessandra Carreiro
# 1     fd3a2f93-e508-44e4-bce1-429658edd555         Lívia Andrade
# 2     5ece1e65-720d-4f4c-9fa1-f9d2544d36eb          Robson Magno
# 3     cbe10555-783c-406a-bf44-2e503502ce48          Andressa fhf
# 4     52f3ef3f-2d7d-42e8-8378-e745da9c1f17    Fernandes Fernando
# ...                                    ...                   ...
# 3894  a6f900f8-9cb3-4080-86e4-ec20fc694aae  Um usuário do Google
# 3895  a070600d-d522-4463-a664-60cdc06cb087  Um usuário do Google
# 3896  41ef1e5a-90a1-4116-a025-f17d8ae49aa5  Um usuário do Google
# 3897  07d97513-3e51-4b56-befb-1203d9826a47  Um usuário do Google
# 3898  92865e25-1b45-4f32-99e9-9196eda0ee06  Um usuário do Google
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/a/ACg8oc...
# 1     https://play-lh.googleusercontent.com/a-/ALV-U...
# ...
